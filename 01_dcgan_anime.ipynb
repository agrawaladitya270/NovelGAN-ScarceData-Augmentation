# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Reshape, Dropout, Dense
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import LeakyReLU , ReLU, PReLU
from tensorflow.keras.layers import Conv2D ,Conv2DTranspose
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
import numpy as np
from PIL import Image
import os
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# Configure tensorflow to only use the gpu (Run this only when you want to train on GPU)
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        print("using GPU")
    except RuntimeError as e:
        print(e)
# Out:
# using GPU

# %%
# Step 1 — copy dataset from Drive to local storage
# !cp -r "/content/drive/MyDrive/Colab Notebooks/Github/images" /content/images

# Step 2 — use local path (FAST)
data_path = "/content/images"

# Step 3 — load dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_path,
    label_mode=None,
    color_mode='rgb',
    batch_size=128,
    image_size=(64, 64),
    shuffle=True
)

# Step 4 — normalize and optimize pipeline
AUTOTUNE = tf.data.AUTOTUNE
train_ds = (
    train_ds
    .map(lambda x: (x/127.5)-1, num_parallel_calls=AUTOTUNE)
    .prefetch(AUTOTUNE)
)

print("Dataset ready!")
# Out:
# Found 63807 files.
# Dataset ready!

# %%
# Weights initializer
init = tf.keras.initializers.RandomNormal(stddev=0.02)

# %%
OUT_DIR = Path("/content/anime_dcgan_results")
IMG_DIR = OUT_DIR / "images"
CKPT_DIR = OUT_DIR / "weights"

IMG_DIR.mkdir(parents=True, exist_ok=True)
CKPT_DIR.mkdir(parents=True, exist_ok=True)

# %%
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

class save_images(keras.callbacks.Callback):
    """
    This is a subclass of the keras.callbacks.Callback class.
    On subclassing it we can specify methods which can be executed while training
    """

    def __init__(self,noise,margin,num_rows,num_cols,**kwargs):
        super(keras.callbacks.Callback,self).__init__(**kwargs)
        self.noise = noise
        self.margin = margin
        self.num_rows = num_rows
        self.num_cols = num_cols

    # overwriting on_epoch_end() helps in executing a custom method when an epoch ends
    def on_epoch_end(self, epoch, logs=None):
        """
        Saves images generated from a fixed random vector by the generator to the disk

        Parameters:
            noise: fixed noise vector from a normal distribution to be fed to the generator.
            num_rows: number of rows of images
            num_cols: number of columns of images
            margin: margin between images
            generator: keras model representing the generator network

        """

        # Generate a base array upon which images can then be added sequentially
        image_array = np.full((
            self.margin + (self.num_rows * (64 + self.margin)),
            self.margin + (self.num_cols * (64 + self.margin)), 3),
            255, dtype=np.uint8)

        # Generate num_rows*num_cols number of images using the generator model
        generated_images = self.model.generator.predict(self.noise)

        # Convert pixel intensities to the range [0,1]
        generated_images = 0.5 * generated_images + 0.5

        #Images need not be converted into the typical [0,255] pixel intensity values because the PIL Image module accepts the range [0,1]


        image_count = 0
        for row in range(self.num_rows):
            for col in range(self.num_cols):
                r = row * (64 + 16) + self.margin
                c = col * (64 + 16) + self.margin
                image_array[r:r + 64, c:c + 64] = generated_images[image_count] * 255
                image_count += 1

        # The image array now contains all the images in an array format which can be stored to the disk

        output_path = 'Epoch_images'
        if not os.path.exists(output_path):
            os.makedirs(output_path)

        filename = os.path.join(output_path, f"train-{epoch+1}.png")
        im = Image.fromarray(image_array)
        im.save(filename)


class checkpoint_callback(keras.callbacks.Callback):
    def __init__(self, **kwargs):
        super(keras.callbacks.Callback, self).__init__(**kwargs)

    def on_epoch_end(self, epoch, logs=None):
        os.makedirs("Weights", exist_ok=True)

        gen_path = f"Weights/generator_epoch_{epoch+1:03d}.weights.h5"
        disc_path = f"Weights/discriminator_epoch_{epoch+1:03d}.weights.h5"

        self.model.generator.save_weights(gen_path)
        self.model.discriminator.save_weights(disc_path)

# %%
def build_generator(seed_size):
    """
    Builds the generator model

    Parameters:
        seed_size: size of the random vector fed into the generator

    Returns:
        model: keras model representing the generator
    """
    model = Sequential()

    # Block - 1
    model.add(Dense(4*4*1024,kernel_initializer=init,input_dim=seed_size))
    model.add(BatchNormalization())
    model.add(ReLU())
    model.add(Reshape((4,4,1024))) # Resulting shape = (4,4,1024)

    # Block - 2
    model.add(Conv2DTranspose(512,kernel_size=5,strides=2,padding='same',use_bias=False,kernel_initializer=init))
    model.add(BatchNormalization())
    model.add(ReLU())  # Resulting shape = (8,8,512)

    # Block - 3
    model.add(Conv2DTranspose(256,kernel_size=5,strides=2,padding='same',use_bias=False,kernel_initializer=init))
    model.add(BatchNormalization())
    model.add(ReLU()) # Resulting shape = (16,16,256)

    # Block - 4
    model.add(Conv2DTranspose(128,kernel_size=3,strides=2,padding='same',use_bias=False,kernel_initializer=init))
    model.add(BatchNormalization())
    model.add(ReLU()) # Resulting shape = (32,32,128)

    # Block - 5
    model.add(Conv2DTranspose(3,kernel_size=3,strides=2,padding='same',use_bias=False,kernel_initializer=init))
    model.add(Activation('tanh')) # Resulting shape = (64,64,3)

    return model

# %%
def build_discriminator(image_length,image_channels):

    """
    Builds the generator model

    Parameters:
        image_length: length of a side of the square image
        image_channels: number of channels in the image

    Returns:
        model: keras model representing the discriminator
    """

    model = Sequential()

    # Block - 1
    model.add(Conv2D(64,kernel_size=3,strides=2,padding='same',use_bias=False,input_shape=(image_length,image_length,image_channels),kernel_initializer=init))
    model.add(LeakyReLU(alpha=0.2)) # Resulting shape = (32,32,64)

    # Block - 2
    model.add(Conv2D(128,kernel_size=3,strides=2,padding='same',use_bias=False,kernel_initializer=init))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2)) # Resulting shape = (16,16,128)

    # Block - 3
    model.add(Conv2D(256,kernel_size=5,strides=2,padding='same',use_bias=False,kernel_initializer=init))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2)) # Resulting shape = (8,8,256)

    # Block - 4
    model.add(Conv2D(512,kernel_size=5,strides=2,padding='same',use_bias=False,kernel_initializer=init))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2)) # Resulting shape = (4,4,512)

    # Block - 5
    model.add(Conv2D(1,kernel_size=4,strides=1,padding='valid',use_bias=False,kernel_initializer=init))
    model.add(Flatten())
    model.add(Activation('sigmoid'))

    return model

# %%
cross_entropy = tf.keras.losses.BinaryCrossentropy()

# %%
class DCGAN(keras.Model):
    """Subclass of the keras.Model class to define custom training step and loss functions"""


    def __init__(self,seed_size,image_length,image_channels,**kwargs):
        """
        Parameters:
            seed_size: size of the random vector for the generator
            image_length: length of a side of the square image
            image_channels: number of channels in the image
        """
        super(DCGAN,self).__init__(**kwargs)

        self.generator = build_generator(seed_size)
        self.discriminator = build_discriminator(image_length,image_channels)
        self.seed_size = seed_size


   # Train generator to give realistic images and penalize it for giving images being classified as fake by the discriminator
    def generator_loss(self,fake_output):
        """
        Parameters:
            fake_output: Tensor containing the respective discriminator's predictions for the batch of images produced
            by generator (fake iamges).

        Returns:
            cross entropy loss between labels for real images (1's) and the discriminator's estimate
        """

        # The objective is to penalize the generator whenever it produces images which the discriminator classifies as 'fake'
        return cross_entropy(tf.ones_like(fake_output), fake_output)


        # smooth parameter is used to induce one sided label smoothing. It can be tuned accordingly
    def discriminator_loss(self,real_output, fake_output,smooth=0.1):
        """
        Parameters:
            real_output: Tensor containing the respective discriminator's predictions for the batch of images taken from
                        the dataset (real images).
            fake_output: Tensor containing the respective discriminator's predictions for the batch of images produced
                        by generator (fake images).

        Returns:
            total_loss: Loss of the discriminator for misclassifying images
        """
        # label for real image is (1-smooth)
        real_loss = cross_entropy(tf.ones_like(real_output)*(1-smooth), real_output)
        fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
        total_loss = real_loss + fake_loss
        return total_loss

    def compile(self,generator_optimizer,discriminator_optimizer):
        """
        configures model for training by adding optimizers

        Parameters:
            generator_optimizer: keras optimizer to be used to train generator.
            discriminator_optimizer: keras optimizer to be used to train discriminator.
        """
        super(DCGAN, self).compile()
        self.generator_optimizer = generator_optimizer
        self.discriminator_optimizer = discriminator_optimizer

    @tf.function
    def train_step(self,data):

        """
        Takes in training data and does a forward pass

        Parameters:
            data: a batch from the training data.
        Returns:
            gen_loss: loss associated with the generator.
            disc_loss: loss associated with the discriminator.

        """

        batch_size = tf.shape(data)[0]

        # feed a random input to generator
        seed = tf.random.normal(shape=(batch_size,self.seed_size))

        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:

            # generate image using generator
            generated_image = self.generator(seed, training = True)

            # discriminator's prediction for real image
            real_output = self.discriminator(data,training = True)

            # discriminator's estimate for fake image
            fake_output = self.discriminator(generated_image,training = True)

            # compute loss
            gen_loss = self.generator_loss(fake_output)
            disc_loss = self.discriminator_loss(real_output,fake_output)

            # optimize generator first
            generator_grad = gen_tape.gradient(gen_loss,self.generator.trainable_variables)
            discriminator_grad = disc_tape.gradient(disc_loss,self.discriminator.trainable_variables)

            # optimize discriminator after generator
            self.generator_optimizer.apply_gradients(zip(generator_grad,self.generator.trainable_variables))
            self.discriminator_optimizer.apply_gradients(zip(discriminator_grad,self.discriminator.trainable_variables))

        return {
            "generator loss": gen_loss,
            "discriminator_loss": disc_loss
        }

# %%
# parameters and hyperparameters
image_length = 64
image_channels = 3
batch_size = 128
seed_size = 128

NUM_ROWS = 4
NUM_COLS = 7
MARGIN = 16

fixed_seed = tf.random.normal(shape=(NUM_ROWS * NUM_COLS, seed_size))
# We are defining a fixed seed because we want to see the generator's images quality by generating the same images every epoch

# %%
generator_optimizer = Adam(learning_rate=0.0002,beta_1=0.5)
discriminator_optimizer = Adam(learning_rate=0.0002,beta_1=0.5)

dcgan = DCGAN(seed_size,image_length,image_channels)
dcgan.compile(generator_optimizer,discriminator_optimizer)

# %%
data_path = "/content/images"

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_path,
    label_mode=None,
    color_mode='rgb',
    batch_size=128,
    image_size=(64, 64),
    shuffle=True
)

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.map(lambda x: (x/127.5)-1).prefetch(AUTOTUNE)
# Out:
# Found 63806 files.

# %%
with tf.device('/GPU:0'):

    #uncomment the next two lines if not training from scratch
    #dcgan.generator.load_weights("Weights/generator_weights.h5")
    #dcgan.discriminator.load_weights("Weights/discriminator_weights.h5")

    history = dcgan.fit(train_ds,epochs=120,batch_size=batch_size,
                        callbacks=[
                            save_images(noise=fixed_seed,num_rows=NUM_ROWS,num_cols=NUM_COLS,margin=MARGIN),
                            checkpoint_callback()
                        ])
# Out:
# Epoch 1/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 245ms/step - discriminator_loss: 1.0684 - generator loss: 1.8934
# Epoch 2/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 243ms/step - discriminator_loss: 0.9523 - generator loss: 1.9597
# Epoch 3/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.9112 - generator loss: 2.1986
# Epoch 4/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.8452 - generator loss: 2.3600
# Epoch 5/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.8039 - generator loss: 2.4849
# Epoch 6/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.7834 - generator loss: 2.4906
# Epoch 7/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.7755 - generator loss: 2.6396
# Epoch 8/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.7374 - generator loss: 2.5544
# Epoch 9/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.7383 - generator loss: 2.6692
# Epoch 10/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.7339 - generator loss: 2.6558
# Epoch 11/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.7192 - generator loss: 2.7026
# Epoch 12/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.7118 - generator loss: 2.7103
# Epoch 13/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.6814 - generator loss: 2.8397
# Epoch 14/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.6837 - generator loss: 2.8296
# Epoch 15/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.6873 - generator loss: 2.7871
# Epoch 16/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.6906 - generator loss: 2.8870
# Epoch 17/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.6392 - generator loss: 2.9134
# Epoch 18/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.6458 - generator loss: 2.9701
# Epoch 19/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.6421 - generator loss: 2.9589
# Epoch 20/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.6798 - generator loss: 2.9453
# Epoch 21/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.6145 - generator loss: 3.0828
# Epoch 22/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5972 - generator loss: 3.1607
# Epoch 23/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 142s 244ms/step - discriminator_loss: 0.6484 - generator loss: 3.0945
# Epoch 24/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.6181 - generator loss: 3.0953
# Epoch 25/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5894 - generator loss: 3.1572
# Epoch 26/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5948 - generator loss: 3.1977
# Epoch 27/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5597 - generator loss: 3.3181
# Epoch 28/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.6279 - generator loss: 3.2159
# Epoch 29/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5757 - generator loss: 3.2685
# Epoch 30/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5931 - generator loss: 3.2109
# Epoch 31/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5721 - generator loss: 3.2387
# Epoch 32/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 142s 244ms/step - discriminator_loss: 0.5723 - generator loss: 3.3374
# Epoch 33/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.6304 - generator loss: 3.1634
# Epoch 34/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5554 - generator loss: 3.3386
# Epoch 35/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.6121 - generator loss: 3.2503
# Epoch 36/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5606 - generator loss: 3.2373
# Epoch 37/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.6509 - generator loss: 3.1391
# Epoch 38/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5508 - generator loss: 3.2828
# Epoch 39/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5174 - generator loss: 3.4741
# Epoch 40/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5824 - generator loss: 3.3363
# Epoch 41/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.6178 - generator loss: 3.1958
# Epoch 42/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5545 - generator loss: 3.3406
# Epoch 43/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 142s 244ms/step - discriminator_loss: 0.5131 - generator loss: 3.5769
# Epoch 44/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5489 - generator loss: 3.4160
# Epoch 45/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5588 - generator loss: 3.4694
# Epoch 46/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5163 - generator loss: 3.7419
# Epoch 47/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.6102 - generator loss: 3.1906
# Epoch 48/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4650 - generator loss: 3.6847
# Epoch 49/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5836 - generator loss: 3.3894
# Epoch 50/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5044 - generator loss: 3.6300
# Epoch 51/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5303 - generator loss: 3.6773
# Epoch 52/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5287 - generator loss: 3.6638
# Epoch 53/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5077 - generator loss: 3.6008
# Epoch 54/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5869 - generator loss: 3.4370
# Epoch 55/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5004 - generator loss: 3.6407
# Epoch 56/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5442 - generator loss: 3.5680
# Epoch 57/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 243ms/step - discriminator_loss: 0.5001 - generator loss: 3.6942
# Epoch 58/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4747 - generator loss: 3.7575
# Epoch 59/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5579 - generator loss: 3.5368
# Epoch 60/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5323 - generator loss: 3.7454
# Epoch 61/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4777 - generator loss: 3.8331
# Epoch 62/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4612 - generator loss: 3.9381
# Epoch 63/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5613 - generator loss: 3.6175
# Epoch 64/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4546 - generator loss: 3.9638
# Epoch 65/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 142s 244ms/step - discriminator_loss: 0.4880 - generator loss: 3.8622
# Epoch 66/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4905 - generator loss: 3.8858
# Epoch 67/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4561 - generator loss: 4.0310
# Epoch 68/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5736 - generator loss: 3.8047
# Epoch 69/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4249 - generator loss: 4.0696
# Epoch 70/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.6180 - generator loss: 3.7821
# Epoch 71/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 142s 244ms/step - discriminator_loss: 0.4363 - generator loss: 3.9120
# Epoch 72/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4943 - generator loss: 3.9440
# Epoch 73/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4422 - generator loss: 4.0494
# Epoch 74/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4842 - generator loss: 4.0442
# Epoch 75/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4426 - generator loss: 4.2107
# Epoch 76/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4601 - generator loss: 4.2368
# Epoch 77/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4373 - generator loss: 4.2636
# Epoch 78/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5597 - generator loss: 3.8321
# Epoch 79/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4274 - generator loss: 4.2402
# Epoch 80/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5873 - generator loss: 3.8214
# Epoch 81/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4255 - generator loss: 4.2266
# Epoch 82/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4651 - generator loss: 4.1224
# Epoch 83/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4735 - generator loss: 4.1970
# Epoch 84/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4548 - generator loss: 4.1706
# Epoch 85/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4662 - generator loss: 4.2063
# Epoch 86/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4576 - generator loss: 4.1813
# Epoch 87/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4657 - generator loss: 4.3683
# Epoch 88/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4638 - generator loss: 4.1540
# Epoch 89/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4090 - generator loss: 4.4930
# Epoch 90/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4888 - generator loss: 4.2714
# Epoch 91/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4040 - generator loss: 4.5247
# Epoch 92/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 142s 244ms/step - discriminator_loss: 0.6357 - generator loss: 3.6314
# Epoch 93/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 243ms/step - discriminator_loss: 0.4052 - generator loss: 4.5199
# Epoch 94/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 142s 244ms/step - discriminator_loss: 0.4249 - generator loss: 4.3857
# Epoch 95/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4215 - generator loss: 4.5634
# Epoch 96/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5655 - generator loss: 3.9522
# Epoch 97/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4061 - generator loss: 4.4757
# Epoch 98/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.3891 - generator loss: 4.7447
# Epoch 99/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5418 - generator loss: 4.0127
# Epoch 100/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4145 - generator loss: 4.5490
# Epoch 101/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.3959 - generator loss: 4.7192
# Epoch 102/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.3996 - generator loss: 4.7271
# Epoch 103/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.7767 - generator loss: 3.2626
# Epoch 104/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4003 - generator loss: 4.4726
# Epoch 105/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4103 - generator loss: 4.5972
# Epoch 106/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4477 - generator loss: 4.6603
# Epoch 107/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4450 - generator loss: 4.3165
# Epoch 108/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.3913 - generator loss: 4.7341
# Epoch 109/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.5339 - generator loss: 4.0082
# Epoch 110/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.3871 - generator loss: 4.7377
# Epoch 111/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4824 - generator loss: 4.6612
# Epoch 112/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4821 - generator loss: 4.0639
# Epoch 113/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.3928 - generator loss: 4.7475
# Epoch 114/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.3981 - generator loss: 4.7306
# Epoch 115/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4490 - generator loss: 4.4854
# Epoch 116/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.3907 - generator loss: 4.8625
# Epoch 117/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 243ms/step - discriminator_loss: 0.4492 - generator loss: 4.6385
# Epoch 118/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4000 - generator loss: 4.6934
# Epoch 119/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4960 - generator loss: 4.7000
# Epoch 120/120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 122s 244ms/step - discriminator_loss: 0.4087 - generator loss: 4.4822

# %%
def generate_faces():
    """Generates random Anime faces"""

    # generate 64 images by giving 64 inputs
    noise = tf.random.normal([64,seed_size])
    generated_images = dcgan.generator(noise)

    fig = plt.figure(figsize=(12,12))
    for i in range(generated_images.shape[0]):
        plt.subplot(8,8,i+1)
        # Convert to range [0,1] for plt.imshow()
        plt.imshow((generated_images[i,:,:,:]*0.5+0.5))
        plt.axis("off")
    plt.show()

# %%
generate_faces()
